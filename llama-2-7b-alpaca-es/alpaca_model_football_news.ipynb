# %% [markdown]
# <a href="https://colab.research.google.com/github/J3SSUS/peruvian-football-news-generator/blob/main/llama-2-7b-alpaca-es/alpaca_model_football_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Llama-2-7b-alpaca-es (Peruvian Football News Article Generator)

# %% [markdown]
# ## Data Format

# %%
import pandas as pd
import numpy as np

# %%
df_football_news = pd.read_csv("full_peruvian_football_news.csv", sep="|", encoding="utf-8")

# %%
df_football_news
# Out:
#                                                 Title  \
# 0   Premio al esfuerzo Piero Quispe fue elegido co...
# 1   A festejar crema así fue la premiación de Univ...
# 2   Se disculpó con Barcos Flores Tienen que venir...
# 3   Liga 1 Quién fue el mejor jugador del fútbol p...
# 4   Yotún jugará en Universitario Jean Ferrari Sí ...
# 5   Equipo centenario Las altas y bajas de Univers...
# 6   Alianza quiere su revancha Las altas y bajas b...
# 7   Hoy celebra el campeón Itinerario de la entreg...
# 8   Se cae Matute Lista de directivos que han renu...
# 9   Se tiene fe para el centenario Piero Quispe Qu...
# 10  Trabajo en menores Conoce a los ganadores del ...
# 11  No pudieron retenerlo Cristal confirmó que Tia...
# 12  El nuevo millonario Conoce cuánto ganará Unive...
# 13  Por eso era Juan Reynoso sorprende al explicar...
# 14  Le respondió a Universitario Barcos Los niños ...
# 15  Inicia la purga en Alianza Lima Mauricio Larri...
# ...

# %%
list_texts = list()
for i in range(len(df_football_news)):
    full_text_new = ''
    full_text_new = "### Instruction" + "\n" + df_football_news.loc[i, 'Title'] + ":" + "\n"
    full_text_new = full_text_new + "### Response" + "\n" + df_football_news.loc[i, 'Text']
    list_texts.append(full_text_new)

df_football_news['Alpaca_format'] = list_texts

# %%
print(df_football_news['Alpaca_format'].values[0])
# Out:
# ### Instruction
# Premio al esfuerzo Piero Quispe fue elegido como el mejor jugador de la Liga 1 2023:
# ### Response
# ...

# %%
series = df_football_news['Alpaca_format']
df_alpaca = pd.DataFrame(series)
df_alpaca.rename(columns={'Alpaca_format':'text'}, inplace=True)
df_alpaca.head()
# Out:
#                                                 text
# 0  ### Instruction\nPremio al esfuerzo Piero Quis...
# 1  ### Instruction\nA festejar crema así fue la p...
# 2  ### Instruction\nSe disculpó con Barcos Flores...
# 3  ### Instruction\nLiga 1 Quién fue el mejor jug...
# 4  ### Instruction\nYotún jugará en Universitario...

# %%
df_alpaca.to_csv("alpaca_peruvian_football_new.csv", index=False)

# %% [markdown]
# ## Fine-tuning the model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_football_news = pd.read_csv("/content/drive/MyDrive/nlp/project-nlp-football/data-alpaca/alpaca_peruvian_football_new.csv", sep="|", encoding="utf-8")

# %%
df_football_news
# Out:
#                                                   text
# 0    ### Instruction\nPremio al esfuerzo Piero Quis...
# 1    ### Instruction\nA festejar crema así fue la p...
# 2    ### Instruction\n¿Se disculpó con Barcos? Flor...
# 3    ### Instruction\nLiga 1 ¿Quién fue el mejor ju...
# 4    ### Instruction\n¿Yotún jugará en Universitari...
# ..                                                 ...
# 292  ### Instruction\nLiga 1 en vilo a poco de su i...
# 293  ### Instruction\nJosé Bellina no descarta a Ch...
# 294  ### Instruction\nEmpieza con triunfo Alianza L...
# 295  ### Instruction\nOficial Universitario confirm...
# 296  ### Instruction\n¿Por qué Alianza Lima rompió ...
#
# [297 rows x 1 columns]

# %%
# !pip3 install autotrain-advanced
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 36.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 25.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 47.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 74.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 39.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 115.4 MB/s eta 0:00:00
# ...

# %%
# !autotrain setup --update-torch
# Out:
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-oy4l56kn
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-oy4l56kn
#   Resolved https://github.com/huggingface/transformers to commit 2fc33ebead50383f7707b17f0e2a178d86347d10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.36.0.dev0-py3-none-any.whl size=7995423 sha256=b2fcbfdde67a4d54a40aeef90e84c50f3e5e976dc4ac46267e8fbd81e580a5b4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-70wzyvo_/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.34.1
#     Uninstalling transformers-4.34.1:
#       Successfully uninstalled transformers-4.34.1
# ...

# %%
# !autotrain llm --train --project_name '/content/drive/MyDrive/nlp/project-nlp-football/alpaca7B' --model 4i-ai/Llama-2-7b-alpaca-es --data_path "/content/drive/MyDrive/nlp/project-nlp-football/data-alpaca" --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 2 --trainer sft
# Out:
# > INFO    Running LLM
# ...

# %% [markdown]
# ## Inference

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, TrainingArguments, GenerationConfig
import torch
model_name = "/content/drive/MyDrive/nlp/project-nlp-football/alpaca7B"

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

def create_and_prepare_model():
        compute_dtype = getattr(torch, "float16")
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=compute_dtype,
            bnb_4bit_use_double_quant=True,
        )
        model = AutoModelForCausalLM.from_pretrained(
            model_name, quantization_config=bnb_config, device_map={"": 0}
        )
        return model
model = create_and_prepare_model()
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
def generate(instruction, input=None):
    #Format the prompt to look like the training data
    if input is not None:
        prompt = "### Instruction:\n"+instruction+"\n\n### Input:\n"+input+"\n\n### Response:\n"
    else :
        prompt = "### Instruction:\n"+instruction+"\n\n### Response:\n"


    inputs = tokenizer(prompt, return_tensors="pt")
    input_ids = inputs["input_ids"].cuda()

    generation_output = model.generate(
            input_ids=input_ids,
            generation_config=GenerationConfig(temperature=1.0, top_p=0.75, top_k=40, num_beams=10), #hyperparameters for generation
            return_dict_in_generate=True,
            output_scores=True,
            max_new_tokens=150, #maximum tokens generated, increase if you want longer asnwer (up to 2048 - the length of the prompt), generation "looks" slower for longer response

    )
    for seq in generation_output.sequences:
        output = tokenizer.decode(seq, skip_special_tokens=True)
        return output.split("### Response:")[1].strip()

# %%
print(generate("Universitario ganó la final:"))
print("--------------------------------")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.75` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:396: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `40` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# ...

# %%
print(generate("Alianza Lima apagó las luces del estadio en la final:"))
print("--------------------------------")
# Out:
# Alianza Lima apagó las luces del estadio en la final:
# Alianza Lima apagó las luces del estadio Alejandro Villanueva en la final del Torneo Clausura 2023 ante Universitario de Deportes. Los blanquiazules ganaron por 1-0 con gol de Hernán Barcos en el minuto 10, pero la luz del estadio se apagó en el minuto 90. Los hinchas de Alianza Lima apagaron las luces del estadio Alejandro Villanueva en la final del Torneo Clausura 2023 ante Universitario de Deportes
# --------------------------------

# %%
print(generate("Todo está listo para la final:"))
print("--------------------------------")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.75` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:396: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `40` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# ...

# %%
print(generate("El torneo Clausura se puso interesante:"))
print("--------------------------------")
# Out:
# El Clausura de la Liga 1 Betsson 2023 se ha posicionado como uno de los torneos más emocionantes de la historia del fútbol peruano. Desde el inicio del campeonato, los clubes más poderosos de la Liga 1, como Universitario de Deportes, Sporting Cristal, Alianza Lima y Cienciano, se han mantenido en las primeras posiciones de la tabla acumulada de la Liga 1 Betsson 2023. Sin embargo, en la segunda mitad del Clausura, el torneo se ha posicionado como uno de los más emocionantes de la historia del fútbol
# --------------------------------

# %%
print(generate("Universitario lo ganó al final del partido:"))
print("--------------------------------")
# Out:
# Universitario lo ganó al final del partido. Universitario de Deportes le ganó 1-0 a Sporting Cristal en el estadio Monumental de Ate, en un duelo válido por la fecha 10 de la Liga 1 Betsson 2023. Con este resultado, los cremas suman 24 puntos en la tabla de posiciones y se ubican en el segundo lugar de la Liga 1 Betsson 2023. Sporting Cristal, por su parte, suma 21 unidades y se ubican en la tercera posición de la tabla de posiciones. Universitario de Deportes y Sporting Cristal
# --------------------------------
